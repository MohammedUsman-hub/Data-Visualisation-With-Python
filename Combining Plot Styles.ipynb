# %%
import numpy as np
import pandas as pd
from numpy.random import randn

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
ds = randn(100)

# %%
sns.distplot(ds, bins=25)
# Out:
# C:\Users\Niko\AppData\Local\Temp\ipykernel_14056\3348266167.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ds, bins=25)
# <Axes: ylabel='Density'>

# %%
sns.distplot(ds, bins=25, rug=True, hist=False)
# Out:
# C:\Users\Niko\AppData\Local\Temp\ipykernel_14056\480064637.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ds, bins=25, rug=True, hist=False)
# <Axes: ylabel='Density'>

# %%
sns.distplot(ds, bins=25, 
            kde_kws = {'color':'indianred', 'label':'KDE PLOT'},
             hist_kws={'color':'blue', 'label':'HIST'})
# Out:
# C:\Users\Niko\AppData\Local\Temp\ipykernel_14056\820794872.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ds, bins=25,
# <Axes: ylabel='Density'>

# %%
from pandas import Series

ser1 = Series(ds, name='My_Data')

ser1
# Out:
# 0     0.172002
# 1     0.309106
# 2    -0.348854
# 3    -0.186416
# 4    -1.159942
#         ...
# 95   -0.457596
# 96   -0.270897
# 97   -0.702425
# 98   -1.093260
# 99   -0.248409
# Name: My_Data, Length: 100, dtype: float64

# %%
sns.distplot(ser1, bins=25)
# Out:
# C:\Users\Niko\AppData\Local\Temp\ipykernel_14056\2261811253.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ser1, bins=25)
# <Axes: xlabel='My_Data', ylabel='Density'>
