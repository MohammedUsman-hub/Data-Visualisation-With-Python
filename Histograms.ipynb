# %%
import numpy as np
import pandas as pd
from numpy.random import randn

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 2.,  4.,  2.,  6., 24., 21., 14., 10., 10.,  7.]),
#  array([-2.29767313, -1.88588148, -1.47408983, -1.06229817, -0.65050652,
#         -0.23871487,  0.17307678,  0.58486843,  0.99666009,  1.40845174,
#          1.82024339]),
#  <BarContainer object of 10 artists>)

# %%
dataset2 = randn(80)

plt.hist(dataset2, color='indianred')
# Out:
# (array([ 1.,  3.,  4.,  9., 15.,  9., 13., 11.,  9.,  6.]),
#  array([-2.80660155, -2.28493026, -1.76325898, -1.2415877 , -0.71991641,
#         -0.19824513,  0.32342615,  0.84509744,  1.36676872,  1.88844   ,
#          2.41011129]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1, color='indianred', alpha=0.5, bins=20)
plt.hist(dataset2, alpha=0.5, bins=20)
# Out:
# (array([1., 0., 0., 3., 1., 3., 1., 8., 7., 8., 2., 7., 6., 7., 7., 4., 8.,
#         1., 3., 3.]),
#  array([-2.80660155, -2.5457659 , -2.28493026, -2.02409462, -1.76325898,
#         -1.50242334, -1.2415877 , -0.98075205, -0.71991641, -0.45908077,
#         -0.19824513,  0.06259051,  0.32342615,  0.5842618 ,  0.84509744,
#          1.10593308,  1.36676872,  1.62760436,  1.88844   ,  2.14927565,
#          2.41011129]),
#  <BarContainer object of 20 artists>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(x=data1, y=data2).annotate(stats.pearsonr) # Works but gives error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sns.jointplot(x=data1, y=data2).annotate(stats.pearsonr)
#
# AttributeError: 'JointGrid' object has no attribute 'annotate'

# %%
sns.jointplot(x=data1, y=data2, kind='hex') # Better visual imo
